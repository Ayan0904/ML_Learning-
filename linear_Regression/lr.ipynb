# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("Housing Price data set.csv")
df.head()
# Out:
#    Unnamed: 0    price  lotsize  bedrooms  bathrms  stories driveway recroom  \
# 0           1  42000.0     5850         3        1        2      yes      no
# 1           2  38500.0     4000         2        1        1      yes      no
# 2           3  49500.0     3060         3        1        1      yes      no
# 3           4  60500.0     6650         3        1        2      yes     yes
# 4           5  61000.0     6360         2        1        1      yes      no
#
#   fullbase gashw airco  garagepl prefarea
# 0      yes    no    no         1       no
# 1       no    no    no         0       no
# 2       no    no    no         0       no
# 3       no    no    no         0       no
# 4       no    no    no         0       no

# %%
# x will consist of lotsize bedrooms batrooms stories 
# y is price 
# y = m1x1 + m2x2 + m3x3 + .... mnxn

dataframe = df[['lotsize','bedrooms','bathrms','stories']].copy()
dataframe
# Out:
#      lotsize  bedrooms  bathrms  stories
# 0       5850         3        1        2
# 1       4000         2        1        1
# 2       3060         3        1        1
# 3       6650         3        1        2
# 4       6360         2        1        1
# ..       ...       ...      ...      ...
# 541     4800         3        2        4
# 542     6000         3        2        4
# 543     6000         3        2        4
# 544     6000         3        2        2
# 545     6000         3        1        2
#
# [546 rows x 4 columns]

# %%
reg = linear_model.LinearRegression()
reg.fit(dataframe,df['price'])
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([5.42917370e+00, 2.82461379e+03, 1.71051745e+04, 7.63489700e+03])

# %%
reg.intercept_
# Out:
# -4009.549979013769

# %%
reg.predict(dataframe)
# Out:
# array([ 68599.9259879 ,  48096.44385342,  45817.63436648,  72943.26494663,
#         60909.29378169,  51789.72543474,  75009.62825879,  67059.5194404 ,
#         55264.39660173,  99074.68365588,  85399.58793471,  42667.270155  ,
#         46068.85513945,  44840.38310076,  45924.77437405,  43671.66728921,
#         54755.53305693,  75530.47387633,  42285.78452971,  65125.60987842,
#         62817.85599908,  81254.62147836,  58555.95464582,  47738.11838932,
#         53308.4506039 ,  50302.16715783,  47010.60911373,  53308.4506039 ,
#         45491.88394457,  61270.54149503,  45381.85700421,  58665.98158618,
#         48096.44385342,  50811.03070263,  68544.19078452,  50811.03070263,
#         48270.17741177,  80177.88187863,  86086.58606996,  60586.82066654,
#         57171.51535272,  61379.124969  ,  64855.23960238, 123281.14667728,
#         44872.99345941,  48566.27504073,  42884.43710293,  53615.40658026,
# ...

# %% [markdown]
# using batch gradient descent algorithm

# %% [markdown]
# using stochastic gradient descent algorithm
